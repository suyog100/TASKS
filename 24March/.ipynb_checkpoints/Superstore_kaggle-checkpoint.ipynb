# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# %matplotlib inline
sns.set(style="darkgrid")

# %%
file_path = r"C:\Users\ACER\Desktop\Sample - Superstore.csv"

# %% [markdown]
# #CSV file is not encoded in UTF-8, which is the default encoding used by pandas.read_csv() ,means that the file has special characters (like non-breaking spaces or smart quotes) that utf-8 can't interpret.

# %%
df = pd.read_csv(file_path, encoding='ISO-8859-1')
# or
# df = pd.read_csv(file_path, encoding='cp1252')

# %%
df.head() #shows the first few rows
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.info() #summary of cols and dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.describe() # basic stats of numerical cols
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %% [markdown]
# cleaning the extra spaces in csv columns if present.

# %%
df.columns = df.columns.str.strip() # removing leading/trailing spaces

# %%
print(df.columns.tolist()) # viewing the cleaned col names
# Out:
# ['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit']

# %%
 #total sales ko hisab
print(f"Total Sales: ${df['Sales'].sum():.2f}")

#total qnty ko hisab
print(f"Total Quantity: {df['Quantity'].sum()}")

#avg dis ko hisab
print(f"Average Discount: {df['Discount'].mean():.2f}")

#total profit ko hisab
print(f"Total Profit: ${df['Profit'].sum():.2f}")
# Out:
# Total Sales: $2297200.86
# Total Quantity: 37873
# Average Discount: 0.16
# Total Profit: $286397.02

# %% [markdown]
# # Chekcing the profit by category

# %%
# Group the data by 'Category' and add up the 'Profit' for each
profit_by_category = df.groupby('Category')['Profit'].sum()

# Create a bar chart to show profit for each category
profit_by_category.plot(kind='bar', title='Profit by Category', ylabel='Profit ($)', xlabel='Category')

# Adjust layout to make the plot fit well
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# # Discount vs Profit scatter plot

# %%
# Create a scatter plot with Discount on the X-axis and Profit on the Y-axis
sns.scatterplot(data=df, x='Discount', y='Profit')  # Shows how profit changes with different discount values

# Add a title to the plot
plt.title('Discount vs Profit')

# Show the scatter plot
plt.show()

# %%
df.columns.tolist() # Print out all the column names so we know what kind of data we have
# Out:
# ['Row ID',
#  'Order ID',
#  'Order Date',
#  'Ship Date',
#  'Ship Mode',
#  'Customer ID',
#  'Customer Name',
#  'Segment',
#  'Country',
#  'City',
#  'State',
#  'Postal Code',
#  'Region',
#  'Product ID',
#  'Category',
#  'Sub-Category',
#  'Product Name',
#  'Sales',
#  'Quantity',
#  'Discount',
#  'Profit']

# %% [markdown]
# # Creating each table one by one

# %% [markdown]
# ## File with only customer info (customer.csv)

# %%
#Imagine organizing a customer contact list and you only want unique customers

#picking only the cols realted to cust info
customer = df[['Customer ID','Customer Name','Segment','Region']]

# Remove duplicates (some customers appear in many orders, but we only need them once)
customer = customer.drop_duplicates()

# Savingcleaned data to a new CSV file
customer.to_csv('customer.csv', index=False)

# %%
customer.head(20)
# Out:
#    Customer ID       Customer Name      Segment   Region
# 0     CG-12520         Claire Gute     Consumer    South
# 2     DV-13045     Darrin Van Huff    Corporate     West
# 3     SO-20335      Sean O'Donnell     Consumer    South
# 5     BH-11710     Brosina Hoffman     Consumer     West
# 12    AA-10480        Andrew Allen     Consumer    South
# 13    IM-15070        Irene Maddox     Consumer     West
# 14    HP-14815       Harold Pawlan  Home Office  Central
# 16    PK-19075           Pete Kriz     Consumer  Central
# 17    AG-10270     Alejandro Grove     Consumer     West
# 18    ZD-21925  Zuschuss Donatelli     Consumer     West
# 21    KB-16585           Ken Black    Corporate  Central
# 23    SF-20065     Sandra Flanagan     Consumer     East
# 24    EB-13870         Emily Burns     Consumer     West
# 25    EH-13945       Eric Hoffmann     Consumer     West
# 27    TB-21520     Tracy Blumstein     Consumer     East
# ...

# %% [markdown]
# # product.csv

# %%
#list every item you sell just once

# Picking only product related columns
product = df[['Product ID', 'Product Name', 'Category', 'Sub-Category']]

# Removed repeated rows as the same product might be sold multiple times
product = product.drop_duplicates()

# Saved it to CSV
product.to_csv('product.csv', index=False)

# %%
product.head()
# Out:
#         Product ID                                       Product Name  \
# 0  FUR-BO-10001798                  Bush Somerset Collection Bookcase
# 1  FUR-CH-10000454  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2  OFF-LA-10000240  Self-Adhesive Address Labels for Typewriters b...
# 3  FUR-TA-10000577      Bretford CR4500 Series Slim Rectangular Table
# 4  OFF-ST-10000760                     Eldon Fold 'N Roll Cart System
#
#           Category Sub-Category
# 0        Furniture    Bookcases
# 1        Furniture       Chairs
# 2  Office Supplies       Labels
# 3        Furniture       Tables
# 4  Office Supplies      Storage

# %% [markdown]
# # Order.csv

# %%
#Each order is like a receipt. Even if it has many products the order ID stays the same.

# Picking order details (linking it to Customer ID so we know who ordered)
order = df[['Order ID', 'Order Date', 'Ship Date', 'Customer ID']]

# Removed repeated orders
order = order.drop_duplicates()

# Saved to CSV
order.to_csv('order.csv', index=False)

# %%
order.head()
# Out:
#           Order ID  Order Date   Ship Date Customer ID
# 0   CA-2016-152156   11/8/2016  11/11/2016    CG-12520
# 2   CA-2016-138688   6/12/2016   6/16/2016    DV-13045
# 3   US-2015-108966  10/11/2015  10/18/2015    SO-20335
# 5   CA-2014-115812    6/9/2014   6/14/2014    BH-11710
# 12  CA-2017-114412   4/15/2017   4/20/2017    AA-10480

# %% [markdown]
# # Shipmode.csv

# %%
# just shows all the ways people can get their stuff delivered

# Get all unique shipping methods
shipmode = df[['Ship Mode']].drop_duplicates()

# Save to CSV
shipmode.to_csv('shipmode.csv', index=False)

# %%
shipmode.head()
# Out:
#           Ship Mode
# 0      Second Class
# 3    Standard Class
# 35      First Class
# 366        Same Day

# %% [markdown]
# # Sales.csv

# %%
# This is the table that connects everything together

sales = df[['Order ID', 'Product ID', 'Customer ID', 'Ship Mode', 'Sales', 'Quantity', 'Discount', 'Profit']]

# Save to CSV
sales.to_csv('sales.csv', index=False)

# %%
sales.head()
# Out:
#          Order ID       Product ID Customer ID       Ship Mode     Sales  \
# 0  CA-2016-152156  FUR-BO-10001798    CG-12520    Second Class  261.9600
# 1  CA-2016-152156  FUR-CH-10000454    CG-12520    Second Class  731.9400
# 2  CA-2016-138688  OFF-LA-10000240    DV-13045    Second Class   14.6200
# 3  US-2015-108966  FUR-TA-10000577    SO-20335  Standard Class  957.5775
# 4  US-2015-108966  OFF-ST-10000760    SO-20335  Standard Class   22.3680
#
#    Quantity  Discount    Profit
# 0         2      0.00   41.9136
# 1         3      0.00  219.5820
# 2         2      0.00    6.8714
# 3         5      0.45 -383.0310
# 4         2      0.20    2.5164

# %% [markdown]
# # xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %%
sns.set_style("whitegrid") 
sns.set_palette("Set2")

# %%
region_sales = df.groupby('Region')['Sales'].sum()
region_sales.plot(kind='bar', title='Sales by Region', xlabel='Region', ylabel='Sales ($)', figsize=(8,5))
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
