# %%
import pandas as pd

# %%
file_path = r"C:\Users\ACER\Desktop\JAVASCRIPT BASICS\Sample - Superstore.csv"

# %%
try:
    df = pd.read_csv(file_path, encoding="utf-8")  # Try UTF-8 first
except UnicodeDecodeError:
    print("UTF-8 failed. Trying ISO-8859-1...")
    df = pd.read_csv(file_path, encoding="ISO-8859-1")  # Fallback encoding
# Out:
# UTF-8 failed. Trying ISO-8859-1...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
order_columns = ["Order ID", "Order Date", "Ship Date", "Ship Mode", "Customer ID", "Segment", "Country", "Region"]
order_df = df[order_columns]

# %%
order_df = order_df.drop_duplicates(subset=["Order ID"])

# %%
order_csv_path = "orders.csv"
order_df.to_csv(order_csv_path, index=False)

print(f"Order-related data saved successfully as '{order_csv_path}'.")
# Out:
# Order-related data saved successfully as 'orders.csv'.

# %%
display(order_df)
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2     CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 5     CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 12    CA-2017-114412   4/15/2017   4/20/2017  Standard Class    AA-10480
# ...              ...         ...         ...             ...         ...
# 9986  CA-2016-125794   9/29/2016   10/3/2016  Standard Class    ML-17410
# 9987  CA-2017-163629  11/17/2017  11/21/2017  Standard Class    RA-19885
# 9989  CA-2014-110422   1/21/2014   1/23/2014    Second Class    TB-21400
# 9990  CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9993  CA-2017-119914    5/4/2017    5/9/2017    Second Class    CC-12220
#
#         Segment        Country Region
# 0      Consumer  United States  South
# ...

# %%
order_columns = ["Row ID", "Order ID", "Order Date", "Ship Date", "Ship Mode", "Country", "Region"]
order_df = df[order_columns]

# %%
order_csv_path = "order_details.csv"
order_df.to_csv(order_csv_path, index=False)
print(f"✅ Order details saved as '{order_csv_path}'")
# Out:
# ✅ Order details saved as 'order_details.csv'

# %%
customer_columns = [ "Customer ID", "Customer Name", "Segment", "City", "State", "Postal Code"]
customer_df = df[customer_columns]

# %%
customer_csv_path = "customer_details.csv"
customer_df.to_csv(customer_csv_path, index=False)
print(f"✅ Customer details saved as '{customer_csv_path}'")
# Out:
# ✅ Customer details saved as 'customer_details.csv'

# %%
print("\n🔹 Order Details Sample:")
display(order_df.head())
# Out:
# 🔹 Order Details Sample:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
#
#          Country Region
# 0  United States  South
# 1  United States  South
# 2  United States   West
# 3  United States  South
# 4  United States  South

# %%
print("\n🔹 Customer Details Sample:")
display(customer_df.head())
# Out:
# 🔹 Customer Details Sample:
#   Customer ID    Customer Name    Segment             City       State  \
# 0    CG-12520      Claire Gute   Consumer        Henderson    Kentucky
# 1    CG-12520      Claire Gute   Consumer        Henderson    Kentucky
# 2    DV-13045  Darrin Van Huff  Corporate      Los Angeles  California
# 3    SO-20335   Sean O'Donnell   Consumer  Fort Lauderdale     Florida
# 4    SO-20335   Sean O'Donnell   Consumer  Fort Lauderdale     Florida
#
#    Postal Code
# 0        42420
# 1        42420
# 2        90036
# 3        33311
# 4        33311
