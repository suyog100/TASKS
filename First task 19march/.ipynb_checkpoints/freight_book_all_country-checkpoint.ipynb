# %%
import requests
from bs4 import BeautifulSoup
import json
import time

# %%
def scrape_freightbook(url):

    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise HTTPError for bad responses (4xx or 5xx)

        soup = BeautifulSoup(response.content, 'html.parser')
        search_results = soup.find('div', class_='search-results')

        if not search_results:
            print("Warning: Could not find 'search-results' div.  Page structure may have changed.")
            return []

        business_cards = search_results.find_all('div', class_='business-card vcard')

        data = []
        for card in business_cards:
            time.sleep(2)  # Delay to avoid rate limiting. Adjust as needed.
            org_div = card.find('div', class_='org')
            if org_div:
                organization = org_div.find('h2').text.strip()

                address_div = card.find('div', class_='street-address')
                address = address_div.text.strip() if address_div else "Address not found"

                country_div = card.find('div', class_='country-name')
                country = country_div.text.strip() if country_div else "Country not found"

                data.append({
                    'organization': organization,
                    'address': address,
                    'country': country
                })
            else:
                print("Warning: Could not find 'org' div in a business card.")

        return data

    except requests.exceptions.RequestException as e:
        print(f"Error during request: {e}")
        return []
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return []

# %%
def main():

    base_url = "https://m.freightbook.net/member/results?country="
    all_data = []

    for country_code in range(1, 247):  # Iterate from 1 to 246
        url = base_url + str(country_code)
        print(f"Scraping country code: {country_code}")
        scraped_data = scrape_freightbook(url)

        if scraped_data:
            all_data.extend(scraped_data)  # Add data to the overall list
            print(f"  Successfully scraped {len(scraped_data)} records for country {country_code}.")
        else:
            print(f"  No data found for country {country_code}. Skipping.")

    if all_data:
        print(f"Successfully scraped a total of {len(all_data)} records.")
        with open('freightbook_all_countries.json', 'w', encoding='utf-8') as f:
            json.dump(all_data, f, indent=4, ensure_ascii=False)  # Ensure proper encoding
        print("Data saved to freightbook_all_countries.json")
    else:
        print("No data scraped for any country.")

# %%
if __name__ == "__main__":
    main()
# Out:
# Scraping country code: 1
#   Successfully scraped 2 records for country 1.
# Scraping country code: 2
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=2
#   No data found for country 2. Skipping.
# Scraping country code: 3
#   No data found for country 3. Skipping.
# Scraping country code: 4
#   No data found for country 4. Skipping.
# Scraping country code: 5
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=5
#   No data found for country 5. Skipping.
# Scraping country code: 6
#   No data found for country 6. Skipping.
# Scraping country code: 7
#   No data found for country 7. Skipping.
# Scraping country code: 8
#   No data found for country 8. Skipping.
# Scraping country code: 9
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=9
#   No data found for country 9. Skipping.
# Scraping country code: 10
#   No data found for country 10. Skipping.
# Scraping country code: 11
#   Successfully scraped 4 records for country 11.
# Scraping country code: 12
#   Successfully scraped 1 records for country 12.
# Scraping country code: 13
#   No data found for country 13. Skipping.
# Scraping country code: 14
#   Successfully scraped 15 records for country 14.
# Scraping country code: 15
#   No data found for country 15. Skipping.
# Scraping country code: 16
#   Successfully scraped 1 records for country 16.
# Scraping country code: 17
#   No data found for country 17. Skipping.
# Scraping country code: 18
#   Successfully scraped 3 records for country 18.
# Scraping country code: 19
#   Successfully scraped 28 records for country 19.
# Scraping country code: 20
#   No data found for country 20. Skipping.
# Scraping country code: 21
#   Successfully scraped 2 records for country 21.
# Scraping country code: 22
#   Successfully scraped 3 records for country 22.
# Scraping country code: 23
#   No data found for country 23. Skipping.
# Scraping country code: 24
#   Successfully scraped 2 records for country 24.
# Scraping country code: 25
#   No data found for country 25. Skipping.
# Scraping country code: 26
#   No data found for country 26. Skipping.
# Scraping country code: 27
#   No data found for country 27. Skipping.
# Scraping country code: 28
#   No data found for country 28. Skipping.
# Scraping country code: 29
#   No data found for country 29. Skipping.
# Scraping country code: 30
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=30
#   No data found for country 30. Skipping.
# Scraping country code: 31
#   Successfully scraped 10 records for country 31.
# Scraping country code: 32
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=32
#   No data found for country 32. Skipping.
# Scraping country code: 33
#   No data found for country 33. Skipping.
# Scraping country code: 34
#   Successfully scraped 4 records for country 34.
# Scraping country code: 35
#   No data found for country 35. Skipping.
# Scraping country code: 36
#   No data found for country 36. Skipping.
# Scraping country code: 37
#   Successfully scraped 3 records for country 37.
# Scraping country code: 38
#   Successfully scraped 3 records for country 38.
# Scraping country code: 39
#   Successfully scraped 15 records for country 39.
# Scraping country code: 40
#   No data found for country 40. Skipping.
# Scraping country code: 41
#   No data found for country 41. Skipping.
# Scraping country code: 42
#   No data found for country 42. Skipping.
# Scraping country code: 43
#   No data found for country 43. Skipping.
# Scraping country code: 44
#   Successfully scraped 2 records for country 44.
# Scraping country code: 45
#   Successfully scraped 61 records for country 45.
# Scraping country code: 46
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=46
#   No data found for country 46. Skipping.
# Scraping country code: 47
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=47
#   No data found for country 47. Skipping.
# Scraping country code: 48
#   Successfully scraped 5 records for country 48.
# Scraping country code: 49
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=49
#   No data found for country 49. Skipping.
# Scraping country code: 50
#   No data found for country 50. Skipping.
# Scraping country code: 51
#   Successfully scraped 1 records for country 51.
# Scraping country code: 52
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=52
#   No data found for country 52. Skipping.
# Scraping country code: 53
#   Successfully scraped 1 records for country 53.
# Scraping country code: 54
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=54
#   No data found for country 54. Skipping.
# Scraping country code: 55
#   No data found for country 55. Skipping.
# Scraping country code: 56
#   No data found for country 56. Skipping.
# Scraping country code: 57
#   Successfully scraped 1 records for country 57.
# Scraping country code: 58
#   Successfully scraped 1 records for country 58.
# Scraping country code: 59
#   Successfully scraped 2 records for country 59.
# Scraping country code: 60
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=60
#   No data found for country 60. Skipping.
# Scraping country code: 61
#   No data found for country 61. Skipping.
# Scraping country code: 62
#   Successfully scraped 2 records for country 62.
# Scraping country code: 63
#   Successfully scraped 2 records for country 63.
# Scraping country code: 64
#   Successfully scraped 18 records for country 64.
# Scraping country code: 65
#   Successfully scraped 2 records for country 65.
# Scraping country code: 66
#   No data found for country 66. Skipping.
# Scraping country code: 67
#   No data found for country 67. Skipping.
# Scraping country code: 68
#   Successfully scraped 2 records for country 68.
# Scraping country code: 69
#   No data found for country 69. Skipping.
# Scraping country code: 70
#   No data found for country 70. Skipping.
# Scraping country code: 71
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=71
#   No data found for country 71. Skipping.
# Scraping country code: 72
#   No data found for country 72. Skipping.
# Scraping country code: 73
#   No data found for country 73. Skipping.
# Scraping country code: 74
#   Successfully scraped 2 records for country 74.
# Scraping country code: 75
#   No data found for country 75. Skipping.
# Scraping country code: 76
#   No data found for country 76. Skipping.
# Scraping country code: 77
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=77
#   No data found for country 77. Skipping.
# Scraping country code: 78
#   No data found for country 78. Skipping.
# Scraping country code: 79
#   No data found for country 79. Skipping.
# Scraping country code: 80
#   Successfully scraped 5 records for country 80.
# Scraping country code: 81
#   Successfully scraped 6 records for country 81.
# Scraping country code: 82
#   Successfully scraped 3 records for country 82.
# Scraping country code: 83
#   Successfully scraped 1 records for country 83.
# Scraping country code: 84
#   Successfully scraped 4 records for country 84.
# Scraping country code: 85
#   No data found for country 85. Skipping.
# Scraping country code: 86
#   No data found for country 86. Skipping.
# Scraping country code: 87
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=87
#   No data found for country 87. Skipping.
# Scraping country code: 88
#   No data found for country 88. Skipping.
# Scraping country code: 89
#   Successfully scraped 1 records for country 89.
# Scraping country code: 90
#   No data found for country 90. Skipping.
# Scraping country code: 91
#   No data found for country 91. Skipping.
# Scraping country code: 92
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=92
#   No data found for country 92. Skipping.
# Scraping country code: 93
#   No data found for country 93. Skipping.
# Scraping country code: 94
#   Successfully scraped 1 records for country 94.
# Scraping country code: 95
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=95
#   No data found for country 95. Skipping.
# Scraping country code: 96
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=96
#   No data found for country 96. Skipping.
# Scraping country code: 97
#   Successfully scraped 2 records for country 97.
# Scraping country code: 98
#   Successfully scraped 9 records for country 98.
# Scraping country code: 99
#   Successfully scraped 1 records for country 99.
# Scraping country code: 100
#   No data found for country 100. Skipping.
# Scraping country code: 101
#   Successfully scraped 84 records for country 101.
# Scraping country code: 102
#   Successfully scraped 11 records for country 102.
# Scraping country code: 103
#   No data found for country 103. Skipping.
# Scraping country code: 104
#   Successfully scraped 2 records for country 104.
# Scraping country code: 105
#   Successfully scraped 1 records for country 105.
# Scraping country code: 106
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=106
#   No data found for country 106. Skipping.
# Scraping country code: 107
#   Successfully scraped 4 records for country 107.
# Scraping country code: 108
#   Successfully scraped 6 records for country 108.
# Scraping country code: 109
#   Successfully scraped 1 records for country 109.
# Scraping country code: 110
#   No data found for country 110. Skipping.
# Scraping country code: 111
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=111
#   No data found for country 111. Skipping.
# Scraping country code: 112
#   Successfully scraped 4 records for country 112.
# Scraping country code: 113
#   Successfully scraped 3 records for country 113.
# Scraping country code: 114
#   Successfully scraped 14 records for country 114.
# Scraping country code: 115
#   No data found for country 115. Skipping.
# Scraping country code: 116
#   No data found for country 116. Skipping.
# Scraping country code: 117
#   Successfully scraped 4 records for country 117.
# Scraping country code: 118
#   Successfully scraped 2 records for country 118.
# Scraping country code: 119
#   Successfully scraped 1 records for country 119.
# Scraping country code: 120
#   Successfully scraped 1 records for country 120.
# Scraping country code: 121
#   Successfully scraped 1 records for country 121.
# Scraping country code: 122
#   Successfully scraped 4 records for country 122.
# Scraping country code: 123
#   No data found for country 123. Skipping.
# Scraping country code: 124
#   No data found for country 124. Skipping.
# Scraping country code: 125
#   No data found for country 125. Skipping.
# Scraping country code: 126
#   No data found for country 126. Skipping.
# Scraping country code: 127
#   Successfully scraped 2 records for country 127.
# Scraping country code: 128
#   No data found for country 128. Skipping.
# Scraping country code: 129
#   No data found for country 129. Skipping.
# Scraping country code: 130
#   No data found for country 130. Skipping.
# Scraping country code: 131
#   No data found for country 131. Skipping.
# Scraping country code: 132
#   No data found for country 132. Skipping.
# Scraping country code: 133
#   Successfully scraped 15 records for country 133.
# Scraping country code: 134
#   Successfully scraped 2 records for country 134.
# Scraping country code: 135
#   Successfully scraped 1 records for country 135.
# Scraping country code: 136
#   Successfully scraped 5 records for country 136.
# Scraping country code: 137
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=137
#   No data found for country 137. Skipping.
# Scraping country code: 138
#   No data found for country 138. Skipping.
# Scraping country code: 139
#   Successfully scraped 2 records for country 139.
# Scraping country code: 140
#   Successfully scraped 2 records for country 140.
# Scraping country code: 141
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=141
#   No data found for country 141. Skipping.
# Scraping country code: 142
#   Successfully scraped 10 records for country 142.
# Scraping country code: 143
#   Successfully scraped 1 records for country 143.
# Scraping country code: 144
#   Successfully scraped 1 records for country 144.
# Scraping country code: 145
#   No data found for country 145. Skipping.
# Scraping country code: 146
#   Successfully scraped 1 records for country 146.
# Scraping country code: 147
#   No data found for country 147. Skipping.
# Scraping country code: 148
#   No data found for country 148. Skipping.
# Scraping country code: 149
#   Successfully scraped 4 records for country 149.
# Scraping country code: 150
#   No data found for country 150. Skipping.
# Scraping country code: 151
#   Successfully scraped 1 records for country 151.
# Scraping country code: 152
#   No data found for country 152. Skipping.
# Scraping country code: 153
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=153
#   No data found for country 153. Skipping.
# Scraping country code: 154
#   Successfully scraped 1 records for country 154.
# Scraping country code: 155
#   Successfully scraped 2 records for country 155.
# Scraping country code: 156
#   No data found for country 156. Skipping.
# Scraping country code: 157
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=157
#   No data found for country 157. Skipping.
# Scraping country code: 158
#   Successfully scraped 5 records for country 158.
# Scraping country code: 159
#   Successfully scraped 1 records for country 159.
# Scraping country code: 160
#   No data found for country 160. Skipping.
# Scraping country code: 161
#   Successfully scraped 11 records for country 161.
# Scraping country code: 162
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=162
#   No data found for country 162. Skipping.
# Scraping country code: 163
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=163
#   No data found for country 163. Skipping.
# Scraping country code: 164
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=164
#   No data found for country 164. Skipping.
# Scraping country code: 165
#   No data found for country 165. Skipping.
# Scraping country code: 166
#   Successfully scraped 2 records for country 166.
# Scraping country code: 167
#   Successfully scraped 42 records for country 167.
# Scraping country code: 168
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=168
#   No data found for country 168. Skipping.
# Scraping country code: 169
#   No data found for country 169. Skipping.
# Scraping country code: 170
#   Successfully scraped 3 records for country 170.
# Scraping country code: 171
#   No data found for country 171. Skipping.
# Scraping country code: 172
#   No data found for country 172. Skipping.
# Scraping country code: 173
#   Successfully scraped 1 records for country 173.
# Scraping country code: 174
#   Successfully scraped 6 records for country 174.
# Scraping country code: 175
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=175
#   No data found for country 175. Skipping.
# Scraping country code: 176
#   Successfully scraped 5 records for country 176.
# Scraping country code: 177
#   Successfully scraped 4 records for country 177.
# Scraping country code: 178
#   No data found for country 178. Skipping.
# Scraping country code: 179
#   Successfully scraped 9 records for country 179.
# Scraping country code: 180
#   No data found for country 180. Skipping.
# Scraping country code: 181
#   Successfully scraped 7 records for country 181.
# Scraping country code: 182
#   No data found for country 182. Skipping.
# Scraping country code: 183
#   Successfully scraped 1 records for country 183.
# Scraping country code: 184
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=184
#   No data found for country 184. Skipping.
# Scraping country code: 185
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=185
#   No data found for country 185. Skipping.
# Scraping country code: 186
#   No data found for country 186. Skipping.
# Scraping country code: 187
#   No data found for country 187. Skipping.
# Scraping country code: 188
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=188
#   No data found for country 188. Skipping.
# Scraping country code: 189
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=189
#   No data found for country 189. Skipping.
# Scraping country code: 190
#   No data found for country 190. Skipping.
# Scraping country code: 191
#   No data found for country 191. Skipping.
# Scraping country code: 192
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=192
#   No data found for country 192. Skipping.
# Scraping country code: 193
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=193
#   No data found for country 193. Skipping.
# Scraping country code: 194
#   Successfully scraped 10 records for country 194.
# Scraping country code: 195
#   Successfully scraped 1 records for country 195.
# Scraping country code: 196
#   Successfully scraped 2 records for country 196.
# Scraping country code: 197
#   No data found for country 197. Skipping.
# Scraping country code: 198
#   No data found for country 198. Skipping.
# Scraping country code: 199
#   Successfully scraped 10 records for country 199.
# Scraping country code: 200
#   No data found for country 200. Skipping.
# Scraping country code: 201
#   Successfully scraped 2 records for country 201.
# Scraping country code: 202
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=202
#   No data found for country 202. Skipping.
# Scraping country code: 203
#   No data found for country 203. Skipping.
# Scraping country code: 204
#   Successfully scraped 10 records for country 204.
# Scraping country code: 205
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=205
#   No data found for country 205. Skipping.
# Scraping country code: 206
#   Successfully scraped 4 records for country 206.
# Scraping country code: 207
#   Successfully scraped 11 records for country 207.
# Scraping country code: 208
#   No data found for country 208. Skipping.
# Scraping country code: 209
#   No data found for country 209. Skipping.
# Scraping country code: 210
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=210
#   No data found for country 210. Skipping.
# Scraping country code: 211
#   No data found for country 211. Skipping.
# Scraping country code: 212
#   No data found for country 212. Skipping.
# Scraping country code: 213
#   Successfully scraped 4 records for country 213.
# Scraping country code: 214
#   No data found for country 214. Skipping.
# Scraping country code: 215
#   Successfully scraped 3 records for country 215.
# Scraping country code: 216
#   No data found for country 216. Skipping.
# Scraping country code: 217
#   Successfully scraped 3 records for country 217.
# Scraping country code: 218
#   Successfully scraped 7 records for country 218.
# Scraping country code: 219
#   No data found for country 219. Skipping.
# Scraping country code: 220
#   Successfully scraped 1 records for country 220.
# Scraping country code: 221
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=221
#   No data found for country 221. Skipping.
# Scraping country code: 222
#   No data found for country 222. Skipping.
# Scraping country code: 223
#   Successfully scraped 1 records for country 223.
# Scraping country code: 224
#   Successfully scraped 3 records for country 224.
# Scraping country code: 225
#   Successfully scraped 33 records for country 225.
# Scraping country code: 226
#   No data found for country 226. Skipping.
# Scraping country code: 227
#   No data found for country 227. Skipping.
# Scraping country code: 228
#   No data found for country 228. Skipping.
# Scraping country code: 229
#   No data found for country 229. Skipping.
# Scraping country code: 230
#   Successfully scraped 7 records for country 230.
# Scraping country code: 231
#   Successfully scraped 30 records for country 231.
# Scraping country code: 232
#   Successfully scraped 27 records for country 232.
# Scraping country code: 233
#   Successfully scraped 35 records for country 233.
# Scraping country code: 234
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=234
#   No data found for country 234. Skipping.
# Scraping country code: 235
#   Successfully scraped 1 records for country 235.
# Scraping country code: 236
#   No data found for country 236. Skipping.
# Scraping country code: 237
#   No data found for country 237. Skipping.
# Scraping country code: 238
#   Successfully scraped 2 records for country 238.
# Scraping country code: 239
#   Successfully scraped 26 records for country 239.
# Scraping country code: 240
#   No data found for country 240. Skipping.
# Scraping country code: 241
#   No data found for country 241. Skipping.
# Scraping country code: 242
# Error during request: 500 Server Error: Internal Server Error for url: https://m.freightbook.net/member/results?country=242
#   No data found for country 242. Skipping.
# Scraping country code: 243
#   No data found for country 243. Skipping.
# Scraping country code: 244
#   No data found for country 244. Skipping.
# Scraping country code: 245
#   No data found for country 245. Skipping.
# Scraping country code: 246
#   Successfully scraped 2 records for country 246.
# Successfully scraped a total of 756 records.
# Data saved to freightbook_all_countries.json
